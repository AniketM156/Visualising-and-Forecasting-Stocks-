# %%
import yfinance as yf

# %%
# sp500 = yf.Ticker("^NSEI")
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period = "max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-01-13 00:00:00-05:00  3960.600098  4003.949951  3947.669922  3999.090088
# 2023-01-17 00:00:00-05:00  3999.280029  4015.389893  3984.570068  3990.969971
# 2023-01-18 00:00:00-05:00  4002.250000  4014.159912  3926.590088  3928.860107
# 2023-01-19 00:00:00-05:00  3911.840088  3922.939941  3885.540039  3898.850098
# 2023-01-20 00:00:00-05:00  3909.040039  3972.959961  3897.860107  3972.610107
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2023-01-06 00:00:00-05:00', '2023-01-09 00:00:00-05:00',
#                '2023-01-10 00:00:00-05:00', '2023-01-11 00:00:00-05:00',
#                '2023-01-12 00:00:00-05:00', '2023-01-13 00:00:00-05:00',
#                '2023-01-17 00:00:00-05:00', '2023-01-18 00:00:00-05:00',
#                '2023-01-19 00:00:00-05:00', '2023-01-20 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=23878, freq=None)

# %%
sp500.plot.line(y="Close",use_index=True)
# sp500.plot.line(y="Low",use_index=True)
# sp500.plot.line(y="High",use_index=True)
# sp500.plot.line(y="Volume",use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Delete unnecesary columns

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-01-13 00:00:00-05:00  3960.600098  4003.949951  3947.669922  3999.090088
# 2023-01-17 00:00:00-05:00  3999.280029  4015.389893  3984.570068  3990.969971
# 2023-01-18 00:00:00-05:00  4002.250000  4014.159912  3926.590088  3928.860107
# 2023-01-19 00:00:00-05:00  3911.840088  3922.939941  3885.540039  3898.850098
# 2023-01-20 00:00:00-05:00  3909.040039  3972.959961  3897.860107  3972.610107
#
# ...

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-01-13 00:00:00-05:00  3960.600098  4003.949951  3947.669922  3999.090088
# 2023-01-17 00:00:00-05:00  3999.280029  4015.389893  3984.570068  3990.969971
# 2023-01-18 00:00:00-05:00  4002.250000  4014.159912  3926.590088  3928.860107
# 2023-01-19 00:00:00-05:00  3911.840088  3922.939941  3885.540039  3898.850098
# 2023-01-20 00:00:00-05:00  3909.040039  3972.959961  3897.860107  3972.610107
#
# ...

# %% [markdown]
# ### Wether the stock price wil go up or down

# %%
sp500["Target"] = (sp500["Tomorrow"]>sp500["Close"]).astype(int)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-01-13 00:00:00-05:00  3960.600098  4003.949951  3947.669922  3999.090088
# 2023-01-17 00:00:00-05:00  3999.280029  4015.389893  3984.570068  3990.969971
# 2023-01-18 00:00:00-05:00  4002.250000  4014.159912  3926.590088  3928.860107
# 2023-01-19 00:00:00-05:00  3911.840088  3922.939941  3885.540039  3898.850098
# 2023-01-20 00:00:00-05:00  3909.040039  3972.959961  3897.860107  3972.610107
#
# ...

# %% [markdown]
# ### Removing values before 1990 due to irrelevence

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2023-01-13 00:00:00-05:00  3960.600098  4003.949951  3947.669922  3999.090088
# 2023-01-17 00:00:00-05:00  3999.280029  4015.389893  3984.570068  3990.969971
# 2023-01-18 00:00:00-05:00  4002.250000  4014.159912  3926.590088  3928.860107
# 2023-01-19 00:00:00-05:00  3911.840088  3922.939941  3885.540039  3898.850098
# 2023-01-20 00:00:00-05:00  3909.040039  3972.959961  3897.860107  3972.610107
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier(n_estimate=1000,min_sample= (experiment the no.),random_state = 1)
model = RandomForestClassifier(n_estimate=100,min_sample=100,random_state = 1)
# cant use Cross Validation in time series analysis
train = sp500.iloc[:-100] # everything except last 100 values
test = sp500.ioc[-100:] # last 100 values

predictors = ["Close","Volume","Open","High","Low"]
model.fit(train[predictors],train["Target"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-3d53a7330f6e> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 # model = RandomForestClassifier(n_estimate=1000,min_sample= (experiment the no.),random_state = 1)
# ----> 3 model = RandomForestClassifier(n_estimate=100,min_sample=100,random_state = 1)
#       4 # cant use Cross Validation in time series analysis
#       5 train = sp500.iloc[:-100] # everything except last 100 values
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# TypeError: __init__() got an unexpected keyword argument 'n_estimate'
